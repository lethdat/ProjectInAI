# %%
import pandas as pd
csv_feature = "radiomics-246patients.csv"
df_feature_  = pd.read_csv(csv_feature,sep='\t')

# %%
df_feature_
# Out:
#      Unnamed: 0       ID  firstorder 10Percentile  firstorder 90Percentile  \
# 0             0  LC01119                    768.0                  65280.0
# 1             1  LC06187                    512.0                  65280.0
# 2             2  LC02473                    768.0                  65280.0
# 3             3  LC01475                    768.0                  65280.0
# 4             4  LC09857                   1024.0                  65280.0
# ..          ...      ...                      ...                      ...
# 224         224  LC09948                    768.0                  65280.0
# 225         225  LC09932                   1024.0                  65280.0
# 226         226  LC10084                    512.0                  65280.0
# 227         227  LC10059                    768.0                  65280.0
# 228         228  LC23886                    768.0                  65280.0
#
# ...
